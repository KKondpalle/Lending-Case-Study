# %%
import os
os.chdir('C:\\Users\\kaust\\OneDrive\\Desktop\\upgrad\\Lending Club Case Study')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('loan.csv')
df.set_index('id', inplace = True)
# Out:
# C:\Users\kaust\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3012: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000           4975.0   36 months
# 1077430    1314167       2500         2500           2500.0   60 months
# 1077175    1313524       2400         2400           2400.0   36 months
# 1076863    1277178      10000        10000          10000.0   36 months
# 1075358    1311748       3000         3000           3000.0   60 months
# ...            ...        ...          ...              ...         ...
# 92187        92174       2500         2500           1075.0   36 months
# 90665        90607       8500         8500            875.0   36 months
# 90395        90390       5000         5000           1325.0   36 months
# 90376        89243       5000         5000            650.0   36 months
# 87023        86999       7500         7500            800.0   36 months
#
#         int_rate  installment grade sub_grade                   emp_title  \
# id
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.drop(df.columns[49:], axis =1, inplace=True)

# %%
df.shape
# Out:
# (39717, 48)

# %%
df.isnull().sum()
# Out:
# member_id                      0
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv                0
# term                           0
# int_rate                       0
# installment                    0
# grade                          0
# sub_grade                      0
# emp_title                   2459
# emp_length                  1075
# home_ownership                 0
# annual_inc                     0
# verification_status            0
# issue_d                        0
# loan_status                    0
# pymnt_plan                     0
# url                            0
# desc                       12940
# purpose                        0
# title                         11
# zip_code                       0
# addr_state                     0
# dti                            0
# delinq_2yrs                    0
# earliest_cr_line               0
# inq_last_6mths                 0
# mths_since_last_delinq     25682
# ...

# %%
df['emp_length'][df.emp_length=='0']='other'
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_34304\3421047620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emp_length'][df.emp_length=='0']='other'

# %%
loan_df = df.fillna(0)

# %%
loan_df.isnull().sum()
# Out:
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# emp_title                  0
# emp_length                 0
# home_ownership             0
# annual_inc                 0
# verification_status        0
# issue_d                    0
# loan_status                0
# pymnt_plan                 0
# url                        0
# desc                       0
# purpose                    0
# title                      0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                0
# earliest_cr_line           0
# inq_last_6mths             0
# mths_since_last_delinq     0
# mths_since_last_record     0
# open_acc                   0
# pub_rec                    0
# revol_bal                  0
# ...

# %%
loan_df['emp_length'][loan_df.emp_length=='0']='other'
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_34304\2010334843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_df['emp_length'][loan_df.emp_length=='0']='other'

# %%
loan_df['emp_length'][loan_df.emp_length == 0] = 'other'
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_34304\3708201775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_df['emp_length'][loan_df.emp_length == 0] = 'other'

# %%
loan_df[loan_df.emp_length == 'other']
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1067644    1302032       2500         2500       2500.00000   36 months
# 1058717    1290516      18000        18000      18000.00000   60 months
# 1064582    1298394       4000         4000       4000.00000   36 months
# 1064366    1298164       1000         1000       1000.00000   36 months
# 1063912    1296491       8250         8250       8250.00000   36 months
# ...            ...        ...          ...              ...         ...
# 480410      610728      10000        10000       9975.00000   36 months
# 480216      610335       3700         3700       3700.00000   36 months
# 479954      609955      10000        10000       9731.17513   36 months
# 479836      609803       6000         6000       6000.00000   36 months
# 479468      609246      25000        25000      23912.90328   36 months
#
#         int_rate  installment grade sub_grade   emp_title emp_length  \
# id
# ...

# %%
loan_df['emp_title'][loan_df.emp_title == 0] = 'other'
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_34304\982586091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_df['emp_title'][loan_df.emp_title == 0] = 'other'

# %%
loan_df[loan_df.emp_title == 'other']
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000           4975.0   36 months
# 1077175    1313524       2400         2400           2400.0   36 months
# 1071795    1306957       5600         5600           5600.0   60 months
# 1032111    1261745       4375         4375           4375.0   36 months
# 1069314    1304202       3000         3000           3000.0   36 months
# ...            ...        ...          ...              ...         ...
# 98276        98268       5400         5400            200.0   36 months
# 93277        93254       3000         3000            950.0   36 months
# 92676        92671       5000         5000            150.0   36 months
# 90395        90390       5000         5000           1325.0   36 months
# 90376        89243       5000         5000            650.0   36 months
#
#         int_rate  installment grade sub_grade emp_title emp_length  \
# id
# ...

# %%
loan_df['title'][loan_df.title == 0] = 'other'
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_34304\2768745085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_df['title'][loan_df.title == 0] = 'other'

# %%
loan_df[loan_df.title == 'other']
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1041645    1271701       6400         6400      6375.000000   60 months
# 1041285    1271519       5000         5000      5000.000000   60 months
# 1016313    1244019       3000         3000      3000.000000   36 months
# 1010794    1237628      25000        25000     24975.000000   60 months
# 908877     1129428      12750        12750     12750.000000   36 months
# 879398     1094275       7200         7200      7200.000000   36 months
# 821846     1030234       2500         2500      2500.000000   36 months
# 798235     1003342       7000         7000      6775.000000   36 months
# 793512      998030       5000         5000      5000.000000   36 months
# 689505      879800      10000        10000      9925.000000   36 months
# 617417      791570       1500         1500      1500.000000   36 months
# 588911      756574       8000         8000      8000.000000   36 months
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
### Analysing the variable term to examine which loan term is preferred by clients
sns.countplot(df['term'])
loan_df['term'].value_counts()
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#  36 months    29096
#  60 months    10621
# Name: term, dtype: int64

# %%
sns.countplot(loan_df['loan_status'])
loan_df['loan_status'].value_counts()
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
## Pie Chart for term
loan_df['term'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='term'>

# %% [markdown]
# ### Histogram for 'loan_amt', 'funded_amt' and 'funded_amt_inv'

# %%
### Histogram for 'loan_amt', 'funded_amt' and 'funded_amt_inv'
plt.hist(loan_df['loan_amnt'], bins=15)
# Out:
# (array([2677., 6911., 5336., 4617., 4246., 4366., 3568., 1447., 2306.,
#          529., 2138.,  294.,  457.,   86.,  739.]),
#  array([  500.,  2800.,  5100.,  7400.,  9700., 12000., 14300., 16600.,
#         18900., 21200., 23500., 25800., 28100., 30400., 32700., 35000.]),
#  <BarContainer object of 15 artists>)

# %%
sns.distplot(loan_df['loan_amnt'])
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='loan_amnt', ylabel='Density'>

# %%
plt.hist(loan_df['funded_amnt'], bins=15)
# Out:
# (array([2711., 6967., 5486., 4728., 4374., 4428., 3622., 1483., 2171.,
#          585., 1796.,  275.,  408.,   78.,  605.]),
#  array([  500.,  2800.,  5100.,  7400.,  9700., 12000., 14300., 16600.,
#         18900., 21200., 23500., 25800., 28100., 30400., 32700., 35000.]),
#  <BarContainer object of 15 artists>)

# %%
sns.distplot(loan_df['funded_amnt'])
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='funded_amnt', ylabel='Density'>

# %%
plt.hist(loan_df['funded_amnt_inv'], bins=15)
# Out:
# (array([2844., 5477., 6972., 5281., 4708., 3933., 3603., 1471., 1891.,
#          737., 1501.,  232.,  427.,   97.,  543.]),
#  array([    0.        ,  2333.33333333,  4666.66666667,  7000.        ,
#          9333.33333333, 11666.66666667, 14000.        , 16333.33333333,
#         18666.66666667, 21000.        , 23333.33333333, 25666.66666667,
#         28000.        , 30333.33333333, 32666.66666667, 35000.        ]),
#  <BarContainer object of 15 artists>)

# %%
sns.distplot(loan_df['funded_amnt_inv'])
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='funded_amnt_inv', ylabel='Density'>

# %%
### Box plot for 'Int_rate'(Interest rate)
sns.boxplot(loan_df['installment'])
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='installment'>

# %% [markdown]
# # Bivariate/ Multivariate analysis

# %%
sns.scatterplot(loan_df['installment'], loan_df['annual_inc'], hue=loan_df['home_ownership'])
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='installment', ylabel='annual_inc'>

# %%
sns.scatterplot(loan_df['installment'], loan_df['annual_inc'], hue=loan_df['home_ownership'], style=loan_df['loan_status'])
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='installment', ylabel='annual_inc'>

# %%
sns.barplot(loan_df['loan_status'],loan_df['total_pymnt'])
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='loan_status', ylabel='total_pymnt'>

# %%
sns.barplot(loan_df['verification_status'],loan_df['total_pymnt'])
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='verification_status', ylabel='total_pymnt'>

# %%
###Income of people who have not paid the loan
sns.distplot(loan_df[loan_df['loan_status']=='Charged Off']['annual_inc'],hist = False)
sns.distplot(loan_df[loan_df['loan_status']=='Current']['annual_inc'], hist= False)
sns.distplot(loan_df[loan_df['loan_status']=='Fully Paid']['annual_inc'], hist= False)
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...
